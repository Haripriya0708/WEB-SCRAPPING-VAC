# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/search?q=lipstick&sid=g9b%2Cffi%2Ctv5%2Cuna&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&as-pos=1&as-type=RECENT&suggestionId=lipstick%7CLipstick&requestId=7b1d0ba7-be80-4004-a4a3-28f050cc7165&as-backfill=on"

# %%
allow = requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
lipstick_name = soup.select(".s1Q9rs")

# %%
lipstick_name
# Out:
# [<a class="s1Q9rs" href="/renee-stay-me-non-transfer-matte-liquid-lip-color-awe-mauve/p/itm34a89e3daf7a2?pid=LSKGA6GNQMQ8SB87&amp;lid=LSTLSKGA6GNQMQ8SB87CSJTCD&amp;marketplace=FLIPKART&amp;q=lipstick&amp;store=g9b%2Fffi%2Ftv5%2Funa&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&amp;fm=organic&amp;iid=en_6PpOWIqBFYtmWeMkiMyATUki10e2Vlyv00Y7E2ysplMCfw5ksi5C%2BmONCddUvP4mxqDRzXzIHYdUDbv9kqsvyw%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=zr29ikvtgg0000001653925546227&amp;qH=0f97737ad54537c5" rel="noopener noreferrer" target="_blank" title="Renee Stay With Me Non Transfer Matte Liquid Lip Color - Awe For Mauve">Renee Stay With Me Non Transfer Matte Liquid Lip Color ...</a>,
# ...

# %%
lipstick = []
junk = []

# %%
for item in lipstick_name:
    lipstick.append(item.text)
    link = "https://www.flipkart.com"
    junk.append(link)

# %%
lipstick
# Out:
# ['Renee Stay With Me Non Transfer Matte Liquid Lip Color ...',
#  'Renee Check Matte Liquid Lip Color - Castle of Nude',
#  'lipsip BEAUTY Set of 12 Liquid Lipsticks Matte Finish L...',
#  'Just Herbs Ayurvedic Lipstick Micro-Mini Trial Kit 38gm',
#  'Sh.Huda 12 pc set Liquid matte lipstick',
#  'THE NYN Insta Beauty Super Stay Water Proof Sensational...',
#  'Lakmé Enrich Matte Lipstick',
#  'Renee Stay With Me Non Transfer Matte Liquid Lip Color ...',
#  'MARS Matte Liquid Lipstick Smudge Proof',
#  'MARS 16 Color Ultra Pigmented Infinity Matte Lip Color ...',
#  'Renee Fab 5 (5 in 1 Lipstick), 7.5g',
#  'Renee Check Matte Liquid Lip Color - Tower of Wine',
#  'Lakmé Forever Matte Liquid Lip Colour -',
#  'RONZILLE Mini Bullet Lipstick Set of 12 Shade A',
#  'SKINPLUS Super stay matte ink bold lip color liquid lip...',
#  'Renee Stay With Me Non Transfer Matte Liquid Lip Color ...',
#  'THE NYN Fab Beauty 5 in 1 Forever Enrich Matte Lipstick...',
# ...

# %%
rate_list = soup.select("._8VNy32 ._30jeq3")

# %%
rate_list
# Out:
# [<div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹281</div>,
#  <div class="_30jeq3">₹371</div>,
#  <div class="_30jeq3">₹319</div>,
#  <div class="_30jeq3">₹138</div>,
#  <div class="_30jeq3">₹191</div>,
#  <div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹259</div>,
#  <div class="_30jeq3">₹219</div>,
#  <div class="_30jeq3">₹569</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹200</div>,
#  <div class="_30jeq3">₹149</div>,
#  <div class="_30jeq3">₹305</div>,
#  <div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹145</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹112</div>,
#  <div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹133</div>,
#  <div class="_30jeq3">₹346</div>,
#  <div class="_30jeq3">₹108</div>,
#  <div class="_30jeq3">₹139</div>,
#  <div class="_30jeq3">₹147</div>,
#  <div class="_30jeq3">₹999</div>,
#  <div class="_30jeq3">₹275</div>,
# ...

# %%
rate = []

# %%
for item in rate_list:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹419',
#  '₹299',
#  '₹281',
#  '₹371',
#  '₹319',
#  '₹138',
#  '₹191',
#  '₹419',
#  '₹259',
#  '₹219',
#  '₹569',
#  '₹299',
#  '₹200',
#  '₹149',
#  '₹305',
#  '₹419',
#  '₹145',
#  '₹199',
#  '₹112',
#  '₹419',
#  '₹133',
#  '₹346',
#  '₹108',
#  '₹139',
#  '₹147',
#  '₹999',
#  '₹275',
#  '₹839',
#  '₹366',
#  '₹165',
#  '₹112',
#  '₹369',
#  '₹181',
#  '₹198',
#  '₹136',
#  '₹125',
#  '₹569',
#  '₹125',
#  '₹265',
#  '₹299']

# %%
import pandas as pd

# %%
lipstick = pd.DataFrame(lipstick,columns=["lipstick_name"])

# %%
lipstick["Rate"]= rate

# %%
lipstick
# Out:
#                                         lipstick_name  Rate
# 0   Renee Stay With Me Non Transfer Matte Liquid L...  ₹419
# 1   Renee Check Matte Liquid Lip Color - Castle of...  ₹299
# 2   lipsip BEAUTY Set of 12 Liquid Lipsticks Matte...  ₹281
# 3   Just Herbs Ayurvedic Lipstick Micro-Mini Trial...  ₹371
# 4             Sh.Huda 12 pc set Liquid matte lipstick  ₹319
# 5   THE NYN Insta Beauty Super Stay Water Proof Se...  ₹138
# 6                         Lakmé Enrich Matte Lipstick  ₹191
# 7   Renee Stay With Me Non Transfer Matte Liquid L...  ₹419
# 8             MARS Matte Liquid Lipstick Smudge Proof  ₹259
# 9   MARS 16 Color Ultra Pigmented Infinity Matte L...  ₹219
# 10                Renee Fab 5 (5 in 1 Lipstick), 7.5g  ₹569
# 11  Renee Check Matte Liquid Lip Color - Tower of ...  ₹299
# 12            Lakmé Forever Matte Liquid Lip Colour -  ₹200
# 13    RONZILLE Mini Bullet Lipstick Set of 12 Shade A  ₹149
# 14  SKINPLUS Super stay matte ink bold lip color l...  ₹305
# ...

# %%
lipstick.to_csv("web scrapping.csv")
